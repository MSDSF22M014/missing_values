# %%
import pandas as pd
df = pd.read_csv('datasets/group-marks.csv')
df.head()
# Out:
#   rollno     name  gender    group    session  age  scholarship     math  \
# 0   MS01   SAADIA  female  group B    MORNING   28         2562  No Idea
# 1   MS02  JUMAIMA  female  group C  AFTERNOON   33         2800       69
# 2   MS03    ARIFA  female      NaN    EVENING   34         3500      NaN
# 3   MS04   SAADIA  female  group A        MOR   44         2000       47
# 4   MS05   DANISH    male  group C  AFTERNOON   54         2100       76
#
#    english  urdu
# 0     72.0    74
# 1     90.0    88
# 2     95.0    93
# 3     57.0    44
# 4     78.0    55

# %%
df.isna().head()
# Out:
#    rollno   name  gender  group  session    age  scholarship   math  english  \
# 0   False  False   False  False    False  False        False  False    False
# 1   False  False   False  False    False  False        False  False    False
# 2   False  False   False   True    False  False        False   True    False
# 3   False  False   False  False    False  False        False  False    False
# 4   False  False   False  False    False  False        False  False    False
#
#     urdu
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
df.notna().head()
# Out:
#    rollno  name  gender  group  session   age  scholarship   math  english  \
# 0    True  True    True   True     True  True         True   True     True
# 1    True  True    True   True     True  True         True   True     True
# 2    True  True    True  False     True  True         True  False     True
# 3    True  True    True   True     True  True         True   True     True
# 4    True  True    True   True     True  True         True   True     True
#
#    urdu
# 0  True
# 1  True
# 2  True
# 3  True
# 4  True

# %%
df.notna().sum()
# Out:
# rollno         50
# name           50
# gender         50
# group          47
# session        50
# age            50
# scholarship    50
# math           46
# english        47
# urdu           50
# dtype: int64

# %%
#calling on a single column or series object
mask = df.math.isna()

# %%
mask.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: math, dtype: bool

# %%
df.loc[mask,:]
# Out:
#    rollno    name  gender    group    session  age  scholarship math  english  \
# 2    MS03   ARIFA  female      NaN    EVENING   34         3500  NaN     95.0
# 5    MS06   SAFIA  female  group B        AFT   23         3800  NaN     83.0
# 23   MS24   LAIBA  female  group C  AFTERNOON   37         3000  NaN     73.0
# 44   MS45  ZAINAB  female  group E        MOR   28         3500  NaN     56.0
#
#     urdu
# 2     93
# 5     78
# 23    73
# 44    54

# %%
import numpy as np
df.replace('No Idea', np.nan, inplace = True)

# %%
df.head()
# Out:
#   rollno     name  gender    group    session  age  scholarship math  english  \
# 0   MS01   SAADIA  female  group B    MORNING   28         2562  NaN     72.0
# 1   MS02  JUMAIMA  female  group C  AFTERNOON   33         2800   69     90.0
# 2   MS03    ARIFA  female      NaN    EVENING   34         3500  NaN     95.0
# 3   MS04   SAADIA  female  group A        MOR   44         2000   47     57.0
# 4   MS05   DANISH    male  group C  AFTERNOON   54         2100   76     78.0
#
#    urdu
# 0    74
# 1    88
# 2    93
# 3    44
# 4    55

# %%
df.math = df.math.astype(float)

# %%
df.head()
# Out:
#   rollno     name  gender    group    session  age  scholarship  math  \
# 0   MS01   SAADIA  female  group B    MORNING   28         2562   NaN
# 1   MS02  JUMAIMA  female  group C  AFTERNOON   33         2800  69.0
# 2   MS03    ARIFA  female      NaN    EVENING   34         3500   NaN
# 3   MS04   SAADIA  female  group A        MOR   44         2000  47.0
# 4   MS05   DANISH    male  group C  AFTERNOON   54         2100  76.0
#
#    english  urdu
# 0     72.0    74
# 1     90.0    88
# 2     95.0    93
# 3     57.0    44
# 4     78.0    55

# %%
mask = df.math.isna()
df.loc[mask,'math'] = df.math.mean()

# %%
df.math.head()
# Out:
# 0    61.644444
# 1    69.000000
# 2    61.644444
# 3    47.000000
# 4    76.000000
# Name: math, dtype: float64

# %%
df.math = df.math.astype(int)

# %%
df['math'].head(10)
# Out:
# 0    61
# 1    69
# 2    61
# 3    47
# 4    76
# 5    61
# 6    88
# 7    40
# 8    64
# 9    38
# Name: math, dtype: int64

# %%
df.math.isna().sum()
# Out:
# 0

# %%
df.head()
# Out:
#   rollno     name  gender    group    session  age  scholarship  math  \
# 0   MS01   SAADIA  female  group B    MORNING   28         2562    61
# 1   MS02  JUMAIMA  female  group C  AFTERNOON   33         2800    69
# 2   MS03    ARIFA  female      NaN    EVENING   34         3500    61
# 3   MS04   SAADIA  female  group A        MOR   44         2000    47
# 4   MS05   DANISH    male  group C  AFTERNOON   54         2100    76
#
#    english  urdu
# 0     72.0    74
# 1     90.0    88
# 2     95.0    93
# 3     57.0    44
# 4     78.0    55

# %%
df.session.isna().sum()
# Out:
# 0

# %%
df.gender.isna().sum()
# Out:
# 0

# %%
df.name.isna().sum()
# Out:
# 0

# %%
mask = df.group.isna()

# %%
df.group.value_counts()
# Out:
# group C    14
# group B    13
# group D    12
# group A     5
# group E     3
# Name: group, dtype: int64

# %%
df.loc[mask,'group'] = df.group.mode()

# %%
df.head()
# Out:
#   rollno     name  gender    group    session  age  scholarship     math  \
# 0   MS01   SAADIA  female  group B    MORNING   28         2562  No Idea
# 1   MS02  JUMAIMA  female  group C  AFTERNOON   33         2800       69
# 2   MS03    ARIFA  female      NaN    EVENING   34         3500      NaN
# 3   MS04   SAADIA  female  group A        MOR   44         2000       47
# 4   MS05   DANISH    male  group C  AFTERNOON   54         2100       76
#
#    english  urdu
# 0     72.0    74
# 1     90.0    88
# 2     95.0    93
# 3     57.0    44
# 4     78.0    55

# %%
df.group.isna().sum()
# Out:
# 3

# %%
df = pd.read_csv('datasets/group-marks.csv', na_values='No Idea')

# %%
df.head()
# Out:
#   rollno     name  gender    group    session  age  scholarship  math  \
# 0   MS01   SAADIA  female  group B    MORNING   28         2562   NaN
# 1   MS02  JUMAIMA  female  group C  AFTERNOON   33         2800  69.0
# 2   MS03    ARIFA  female      NaN    EVENING   34         3500   NaN
# 3   MS04   SAADIA  female  group A        MOR   44         2000  47.0
# 4   MS05   DANISH    male  group C  AFTERNOON   54         2100  76.0
#
#    english  urdu
# 0     72.0    74
# 1     90.0    88
# 2     95.0    93
# 3     57.0    44
# 4     78.0    55

# %%
df.math.fillna(value = df.math.mean(), inplace = True)
df.math.isna().sum()
# Out:
# 0

# %%
df.group.fillna(method = 'bfill', inplace = True)
df.group.isna().sum()
# Out:
# 0

# %%
dict1 ={
     'MORNING' : 'MOR',
    'MOR' : 'MOR',
    'AFTERNOON' : 'AFT',
    'AFT': 'AFT',
    'EVENING' : 'EVE',
    'EVE': 'EVE'
}
df.session = df.session.map(dict1)

# %%
df.head()
# Out:
#   rollno     name  gender    group session  age  scholarship       math  \
# 0   MS01   SAADIA  female  group B     MOR   28         2562  61.644444
# 1   MS02  JUMAIMA  female  group C     AFT   33         2800  69.000000
# 2   MS03    ARIFA  female  group A     EVE   34         3500  61.644444
# 3   MS04   SAADIA  female  group A     MOR   44         2000  47.000000
# 4   MS05   DANISH    male  group C     AFT   54         2100  76.000000
#
#    english  urdu
# 0     72.0    74
# 1     90.0    88
# 2     95.0    93
# 3     57.0    44
# 4     78.0    55

# %%
df['scholarship in $'] = df.scholarship.map(lambda x: x/200)

# %%
df.head(
)
# Out:
#   rollno     name  gender    group session  age  scholarship       math  \
# 0   MS01   SAADIA  female  group B     MOR   28         2562  61.644444
# 1   MS02  JUMAIMA  female  group C     AFT   33         2800  69.000000
# 2   MS03    ARIFA  female  group A     EVE   34         3500  61.644444
# 3   MS04   SAADIA  female  group A     MOR   44         2000  47.000000
# 4   MS05   DANISH    male  group C     AFT   54         2100  76.000000
#
#    english  urdu  scholarship in $
# 0     72.0    74             12.81
# 1     90.0    88             14.00
# 2     95.0    93             17.50
# 3     57.0    44             10.00
# 4     78.0    55             10.50

# %%
df1 = df.dropna()

# %%
df1.shape
# Out:
# (47, 10)

# %%
del df['scholarship in $']
#del df.scholarship in $ cannot be used . operator

# %%
df2 = df.dropna(axis = 0, how = 'any', subset = ['math'])

# %%
import pandas as pd
df1 = pd.read_csv('datasets/group-marks.csv')
df1.head()
# Out:
#   rollno     name  gender    group    session  age  scholarship     math  \
# 0   MS01   SAADIA  female  group B    MORNING   28         2562  No Idea
# 1   MS02  JUMAIMA  female  group C  AFTERNOON   33         2800       69
# 2   MS03    ARIFA  female      NaN    EVENING   34         3500      NaN
# 3   MS04   SAADIA  female  group A        MOR   44         2000       47
# 4   MS05   DANISH    male  group C  AFTERNOON   54         2100       76
#
#    english  urdu
# 0     72.0    74
# 1     90.0    88
# 2     95.0    93
# 3     57.0    44
# 4     78.0    55

# %%
df2 = pd.get_dummies(df1[['gender']])
df2.head()
# Out:
#    gender_female  gender_male
# 0              1            0
# 1              1            0
# 2              1            0
# 3              1            0
# 4              0            1

# %%
df2 = pd.get_dummies(df1[['gender']], drop_first=True)
df2.head()
# Out:
#    gender_male
# 0            0
# 1            0
# 2            0
# 3            0
# 4            1

# %%
df3 = df1.join(df2['gender_male'])
df3.head()
# Out:
#   rollno     name  gender    group    session  age  scholarship     math  \
# 0   MS01   SAADIA  female  group B    MORNING   28         2562  No Idea
# 1   MS02  JUMAIMA  female  group C  AFTERNOON   33         2800       69
# 2   MS03    ARIFA  female      NaN    EVENING   34         3500      NaN
# 3   MS04   SAADIA  female  group A        MOR   44         2000       47
# 4   MS05   DANISH    male  group C  AFTERNOON   54         2100       76
#
#    english  urdu  gender_male
# 0     72.0    74            0
# 1     90.0    88            0
# 2     95.0    93            0
# 3     57.0    44            0
# 4     78.0    55            1

# %%
df3.session.value_counts()
dict1 = {
    'MORNING' : 'MOR',
    'AFTERNOON' : 'AFT',
}
df3.session = df3.session.map(dict1)
#df.session = df.session.replace(dict1)

# %%
df3.head()
# Out:
#   rollno     name  gender    group session  age  scholarship     math  \
# 0   MS01   SAADIA  female  group B     NaN   28         2562  No Idea
# 1   MS02  JUMAIMA  female  group C     NaN   33         2800       69
# 2   MS03    ARIFA  female      NaN     NaN   34         3500      NaN
# 3   MS04   SAADIA  female  group A     NaN   44         2000       47
# 4   MS05   DANISH    male  group C     NaN   54         2100       76
#
#    english  urdu  gender_male
# 0     72.0    74            0
# 1     90.0    88            0
# 2     95.0    93            0
# 3     57.0    44            0
# 4     78.0    55            1
